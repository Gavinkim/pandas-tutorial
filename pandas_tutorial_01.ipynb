# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./gapminder.tsv',sep='\t')

# %%
df.head(2)
# Out:
#        country continent  year  lifeExp      pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801  8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332  9240934  820.853030

# %%
df.columns
# Out:
# Index(['country', 'continent', 'year', 'lifeExp', 'pop', 'gdpPercap'], dtype='object')

# %%
df.dtypes
# Out:
# country       object
# continent     object
# year           int64
# lifeExp      float64
# pop            int64
# gdpPercap    float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    1704 non-null   object
#  1   continent  1704 non-null   object
#  2   year       1704 non-null   int64
#  3   lifeExp    1704 non-null   float64
#  4   pop        1704 non-null   int64
#  5   gdpPercap  1704 non-null   float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 80.0+ KB

# %%
country_df = df['country']
country_df.head()
# Out:
# 0    Afghanistan
# 1    Afghanistan
# 2    Afghanistan
# 3    Afghanistan
# 4    Afghanistan
# Name: country, dtype: object

# %%
subset = df[['country','continent','year']]
subset.head()
# Out:
#        country continent  year
# 0  Afghanistan      Asia  1952
# 1  Afghanistan      Asia  1957
# 2  Afghanistan      Asia  1962
# 3  Afghanistan      Asia  1967
# 4  Afghanistan      Asia  1972

# %%
df.shape[0]
# Out:
# 1704

# %%
small_range=list(range(5))
print(small_range)
subset = df.iloc[:,small_range]
subset.head()
# Out:
# [0, 1, 2, 3, 4]
#        country continent  year  lifeExp       pop
# 0  Afghanistan      Asia  1952   28.801   8425333
# 1  Afghanistan      Asia  1957   30.332   9240934
# 2  Afghanistan      Asia  1962   31.997  10267083
# 3  Afghanistan      Asia  1967   34.020  11537966
# 4  Afghanistan      Asia  1972   36.088  13079460

# %%
#lifeExp 열을 연도별로 그룹화하여 평균 계산
groupby_year_df = df.groupby('year')['lifeExp'].mean()
groupby_year_df
# Out:
# year
# 1952    49.057620
# 1957    51.507401
# 1962    53.609249
# 1967    55.678290
# 1972    57.647386
# 1977    59.570157
# 1982    61.533197
# 1987    63.212613
# 1992    64.160338
# 1997    65.014676
# 2002    65.694923
# 2007    67.007423
# Name: lifeExp, dtype: float64

# %%
#연도별로 그룹화 한 후 lifeExp 의 평균을 구한다.
grouped_year_df = df.groupby('year')
grouped_year_df['lifeExp'].mean()
# Out:
# year
# 1952    49.057620
# 1957    51.507401
# 1962    53.609249
# 1967    55.678290
# 1972    57.647386
# 1977    59.570157
# 1982    61.533197
# 1987    63.212613
# 1992    64.160338
# 1997    65.014676
# 2002    65.694923
# 2007    67.007423
# Name: lifeExp, dtype: float64

# %%
#연도, 지역별로 그룹화 하여 lifeExp,gdpPercap 의 평균 값을 구하기.
multi_group_var = df.groupby(['year','continent'])[['lifeExp','gdpPercap']].mean()
multi_group_var
# Out:
#                   lifeExp     gdpPercap
# year continent
# 1952 Africa     39.135500   1252.572466
#      Americas   53.279840   4079.062552
#      Asia       46.314394   5195.484004
#      Europe     64.408500   5661.057435
#      Oceania    69.255000  10298.085650
# 1957 Africa     41.266346   1385.236062
#      Americas   55.960280   4616.043733
#      Asia       49.318544   5787.732940
#      Europe     66.703067   6963.012816
#      Oceania    70.295000  11598.522455
# 1962 Africa     43.319442   1598.078825
#      Americas   58.398760   4901.541870
#      Asia       51.563223   5729.369625
#      Europe     68.539233   8365.486814
#      Oceania    71.085000  12696.452430
# 1967 Africa     45.334538   2050.363801
#      Americas   60.410920   5668.253496
#      Asia       54.663640   5971.173374
#      Europe     69.737600  10143.823757
#      Oceania    71.310000  14495.021790
# 1972 Africa     47.450942   2339.615674
#      Americas   62.394920   6491.334139
# ...

# %%
#그룹화한 데이터 개수
#그룹화한 데이터의 개수가 몇개인지를 통계에서는 빈도수 라고 한다.
df.groupby('continent')['country'].nunique()
# Out:
# continent
# Africa      52
# Americas    25
# Asia        33
# Europe      30
# Oceania      2
# Name: country, dtype: int64

# %%
df.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
#append,concat 메서드 사용시 ignore_index -> True 일 경우 인덱스를 0부터 다시 지정됨

# %%
person = pd.read_csv('survey_person.csv')
site=pd.read_csv('survey_site.csv')
survey=pd.read_csv('survey_survey.csv')
visited=pd.read_csv('survey_visited.csv')

# %%
visited_subset=visited.loc[[0,2,6]]

# %%
#merge: 기본은 내부 조인이며, merge 를 콜한 df 가 왼쪽으로 지정되고, 첫번째 인자값으로 지정한 df 를 오른쪽으로 지정.
#왼쪽 df 의 열과, 오른쪽 df 의 열의 값이 일치하면 왼쪽 df 기준으로 연결한다.
o2o_merge=site.merge(visited_subset, left_on='name', right_on='site')
o2o_merge
# Out:
#     name    lat    long  ident   site       dated
# 0   DR-1 -49.85 -128.57    619   DR-1  1927-02-08
# 1   DR-3 -47.15 -126.72    734   DR-3  1939-01-07
# 2  MSK-4 -48.87 -123.40    837  MSK-4  1932-01-14

# %%
# merge 사용시 전달하는 값을 여러개 사용
ps = person.merge(survey, left_on='ident', right_on='person')
vs = visited.merge(survey, left_on='ident',right_on='taken')
ps_vs = ps.merge(vs, left_on=['ident','taken','quant','reading'],right_on=['person','ident','quant','reading'])
ps_vs
# Out:
#    ident_x   personal   family  taken_x person_x quant  reading  ident_y  \
# 0     dyer    William     Dyer      619     dyer   rad     9.82      619
# 1     dyer    William     Dyer      619     dyer   sal     0.13      619
# 2     dyer    William     Dyer      622     dyer   rad     7.80      622
# 3     dyer    William     Dyer      622     dyer   sal     0.09      622
# 4       pb      Frank  Pabodie      734       pb   rad     8.41      734
# 5       pb      Frank  Pabodie      734       pb  temp   -21.50      734
# 6       pb      Frank  Pabodie      735       pb   rad     7.22      735
# 7       pb      Frank  Pabodie      751       pb   rad     4.35      751
# 8       pb      Frank  Pabodie      751       pb  temp   -18.50      751
# 9     lake   Anderson     Lake      734     lake   sal     0.05      734
# 10    lake   Anderson     Lake      751     lake   sal     0.10      751
# 11    lake   Anderson     Lake      752     lake   rad     2.19      752
# ...

# %%
ps_vs.loc[0,]
# Out:
# ident_x           dyer
# personal       William
# family            Dyer
# taken_x            619
# person_x          dyer
# quant              rad
# reading           9.82
# ident_y            619
# site              DR-1
# dated       1927-02-08
# taken_y            619
# person_y          dyer
# Name: 0, dtype: object

# %%
#누락값 개수
ebola=pd.read_csv('country_timeseries.csv')
ebola.count()
num_rows = ebola.shape[0]
num_missing=num_rows - ebola.count()
num_missing
# Out:
# Date                     0
# Day                      0
# Cases_Guinea            29
# Cases_Liberia           39
# Cases_SierraLeone       35
# Cases_Nigeria           84
# Cases_Senegal           97
# Cases_UnitedStates     104
# Cases_Spain            106
# Cases_Mali             110
# Deaths_Guinea           30
# Deaths_Liberia          41
# Deaths_SierraLeone      35
# Deaths_Nigeria          84
# Deaths_Senegal         100
# Deaths_UnitedStates    104
# Deaths_Spain           106
# Deaths_Mali            110
# dtype: int64

# %%
np.count_nonzero(ebola.isnull())
# Out:
# 1214

# %%
np.count_nonzero(ebola['Cases_Guinea'].isnull())
# Out:
# 29

# %%
# 시리즈의 지정열의 빈도구하기
ebola.Cases_Guinea.value_counts(dropna=False).head()
# Out:
# NaN      29
# 86.0      3
# 495.0     2
# 112.0     2
# 390.0     2
# Name: Cases_Guinea, dtype: int64

# %%
#상관계수
# 모든 열의 상관계수
ebola.corr()
# Out:
#                           Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# Day                  1.000000      0.932306       0.905787           0.883573
# Cases_Guinea         0.932306      1.000000       0.989144           0.988683
# Cases_Liberia        0.905787      0.989144       1.000000           0.971197
# Cases_SierraLeone    0.883573      0.988683       0.971197           1.000000
# Cases_Nigeria        0.715437      0.629051       0.636440           0.542299
# Cases_Senegal       -0.284158     -0.279143      -0.319454          -0.248758
# Cases_UnitedStates   0.780362      0.851292       0.991281           0.785832
# Cases_Spain               NaN           NaN            NaN                NaN
# Cases_Mali           0.914735      0.894327       1.000000           0.885561
# Deaths_Guinea        0.934977      0.997306       0.976828           0.990125
# Deaths_Liberia       0.920150      0.977195       0.989716           0.949108
# ...

# %%
# 특정열의 상관계수
ebola[['Day','Cases_Guinea']].corr()
# Out:
#                    Day  Cases_Guinea
# Day           1.000000      0.932306
# Cases_Guinea  0.932306      1.000000
